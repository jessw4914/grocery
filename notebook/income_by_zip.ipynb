# %%
import pandas as pd

# %%
income=pd.read_csv('../data/Mean_income-2022-12-07T010142.csv')

# %%
income.head()
# Out:
#                           Label (Grouping) Tennessee!!Number!!Estimate  \
# 0                         HOUSEHOLD INCOME                         NaN
# 1                           All households                   2,770,395
# 2                            With earnings                   2,092,347
# 3              With wages or salary income                   2,005,687
# 4              With self-employment income                     312,186
#
#   Tennessee!!Number!!Margin of Error  \
# 0                                NaN
# 1                             ±8,851
# 2                            ±12,627
# 3                            ±13,256
# 4                             ±8,973
#
#   Tennessee!!Percent Distribution!!Estimate  \
# 0                                       NaN
# 1                                 2,770,395
# 2                                     75.5%
# 3                                     72.4%
# 4                                     11.3%
#
# ...

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Label (Grouping)                                                    32 non-null     object
#  1   Tennessee!!Number!!Estimate                                         28 non-null     object
#  2   Tennessee!!Number!!Margin of Error                                  28 non-null     object
#  3   Tennessee!!Percent Distribution!!Estimate                           28 non-null     object
#  4   Tennessee!!Percent Distribution!!Margin of Error                    28 non-null     object
#  5   Tennessee!!Mean income (dollars)!!Estimate                          28 non-null     object
#  6   Tennessee!!Mean income (dollars)!!Margin of Error                   28 non-null     object
# ...

# %%
income_2020=pd.read_csv('../data/incom_by_zip_2022-12-09T020507.csv')

# %%
income_2020.head()
# Out:
#           Label (Grouping)        Total Total!!Less than $10,000  \
# 0            United States          NaN                      NaN
# 1               Households          NaN                      NaN
# 2                 Estimate  122,354,219                     5.8%
# 3          Margin of Error     ±211,970                     ±0.1
# 4                 Families          NaN                      NaN
#
#   Total!!$10,000 to $14,999 Total!!$15,000 to $24,999  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                      4.1%                      8.5%
# 3                      ±0.1                      ±0.1
# 4                       NaN                       NaN
#
#   Total!!$25,000 to $34,999 Total!!$35,000 to $49,999  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                      8.6%                     12.0%
# ...

# %%
income_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 18 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Label (Grouping)                                           299 non-null    object
#  1   Total                                                      184 non-null    object
#  2   Total!!Less than $10,000                                   184 non-null    object
#  3   Total!!$10,000 to $14,999                                  184 non-null    object
#  4   Total!!$15,000 to $24,999                                  184 non-null    object
#  5   Total!!$25,000 to $34,999                                  184 non-null    object
#  6   Total!!$35,000 to $49,999                                  184 non-null    object
#  7   Total!!$50,000 to $74,999                                  184 non-null    object
# ...

# %%
##income_2020=income_2020[income_2020['Label (Grouping)'].str.contains('372$',case=True,regex=True)]
print(income_2020[income_2020['Label (Grouping)'].str.contains('372$',case=True,regex=True)])
# Out:
# Empty DataFrame
# Columns: [Label (Grouping), Total, Total!!Less than $10,000, Total!!$10,000 to $14,999, Total!!$15,000 to $24,999, Total!!$25,000 to $34,999, Total!!$35,000 to $49,999, Total!!$50,000 to $74,999, Total!!$75,000 to $99,999, Total!!$100,000 to $149,999, Total!!$150,000 to $199,999, Total!!$200,000 or more, Median income (dollars), Mean income (dollars), PERCENT ALLOCATED, PERCENT ALLOCATED!!Household income in the past 12 months, PERCENT ALLOCATED!!Family income in the past 12 months, PERCENT ALLOCATED!!Nonfamily income in the past 12 months]
# Index: []

# %% [markdown]
# nope

# %%
income_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 18 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Label (Grouping)                                           299 non-null    object
#  1   Total                                                      184 non-null    object
#  2   Total!!Less than $10,000                                   184 non-null    object
#  3   Total!!$10,000 to $14,999                                  184 non-null    object
#  4   Total!!$15,000 to $24,999                                  184 non-null    object
#  5   Total!!$25,000 to $34,999                                  184 non-null    object
#  6   Total!!$35,000 to $49,999                                  184 non-null    object
#  7   Total!!$50,000 to $74,999                                  184 non-null    object
# ...

# %%
income_2020 = income_2020.drop(columns=['PERCENT ALLOCATED','PERCENT ALLOCATED!!Household income in the past 12 months', 'PERCENT ALLOCATED!!Family income in the past 12 months', 'PERCENT ALLOCATED!!Nonfamily income in the past 12 months'], axis = 1)

# %%
income_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Label (Grouping)             299 non-null    object
#  1   Total                        184 non-null    object
#  2   Total!!Less than $10,000     184 non-null    object
#  3   Total!!$10,000 to $14,999    184 non-null    object
#  4   Total!!$15,000 to $24,999    184 non-null    object
#  5   Total!!$25,000 to $34,999    184 non-null    object
#  6   Total!!$35,000 to $49,999    184 non-null    object
#  7   Total!!$50,000 to $74,999    184 non-null    object
#  8   Total!!$75,000 to $99,999    184 non-null    object
#  9   Total!!$100,000 to $149,999  184 non-null    object
#  10  Total!!$150,000 to $199,999  184 non-null    object
#  11  Total!!$200,000 or more      184 non-null    object
#  12  Median income (dollars)      184 non-null    object
# ...

# %%
income_2020.columns=['zip_code', 'Total', 'Less_than_10,000', '10,000_to_14,999', '15,000_to_24,999', '25,000_to_34,999', '35,000_to_49,999' , '50,000_to_79,999', '75,000_to_99,999', '100,000_to_149,999','150,000_to_199,999', '200,000_or_more', 'median', 'mean']

# %%
income_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   zip_code            299 non-null    object
#  1   Total               184 non-null    object
#  2   Less_than_10,000    184 non-null    object
#  3   10,000_to_14,999    184 non-null    object
#  4   15,000_to_24,999    184 non-null    object
#  5   25,000_to_34,999    184 non-null    object
#  6   35,000_to_49,999    184 non-null    object
#  7   50,000_to_79,999    184 non-null    object
#  8   75,000_to_99,999    184 non-null    object
#  9   100,000_to_149,999  184 non-null    object
#  10  150,000_to_199,999  184 non-null    object
#  11  200,000_or_more     184 non-null    object
#  12  median              184 non-null    object
#  13  mean                184 non-null    object
# dtypes: object(14)
# memory usage: 32.8+ KB

# %%
income_2020.head()
# Out:
#                   zip_code        Total Less_than_10,000 10,000_to_14,999  \
# 0            United States          NaN              NaN              NaN
# 1               Households          NaN              NaN              NaN
# 2                 Estimate  122,354,219             5.8%             4.1%
# 3          Margin of Error     ±211,970             ±0.1             ±0.1
# 4                 Families          NaN              NaN              NaN
#
#   15,000_to_24,999 25,000_to_34,999 35,000_to_49,999 50,000_to_79,999  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2             8.5%             8.6%            12.0%            17.2%
# 3             ±0.1             ±0.1             ±0.1             ±0.1
# 4              NaN              NaN              NaN              NaN
#
#   75,000_to_99,999 100,000_to_149,999 150,000_to_199,999 200,000_or_more  \
# ...

# %%
income_2020.zip_code.apply(lambda x: x.strip('ZCTA5'))
# Out:
# 0                 United States
# 1                    Households
# 2                      Estimate
# 3               Margin of Error
# 4                      Families
#                  ...
# 294                    Estimate
# 295             Margin of Error
# 296        Nonfamily households
# 297                    Estimate
# 298             Margin of Error
# Name: zip_code, Length: 299, dtype: object

# %%
income_by_zip=pd.read_csv('../data/2020_census_income.csv')

# %%
income_by_zip.head(5)
# Out:
#      ZIP        type     Label population Unnamed: 4 Less than $10,000  \
# 0  37201  Households  Estimate        620        620             18.9%
# 1  37203  Households  Estimate     10,201     10,201             11.9%
# 2  37204  Households  Estimate      6,080      6,080              4.1%
# 3  37205  Households  Estimate     10,999        NaN              4.6%
# 4  37206  Households  Estimate     11,584        NaN              8.4%
#
#   $10,000 to $14,999 $15,000 to $24,999 $25,000 to $34,999 $35,000 to $49,999  \
# 0               0.0%               0.0%               2.6%               4.5%
# 1               4.5%               7.8%               4.2%              12.8%
# 2               1.6%               4.3%               6.0%              10.1%
# 3               1.4%               4.0%               4.2%               7.5%
# 4               4.4%               8.5%               6.9%               9.0%
#
#   $50,000 to $74,999 $75,000 to $99,999 $100,000 to $149,999  \
# ...

# %%
income_by_zip = income_by_zip.drop(columns =['type','Label', 'Unnamed: 4' ])
income_by_zip.head(5)
# Out:
#      ZIP population Less than $10,000 $10,000 to $14,999 $15,000 to $24,999  \
# 0  37201        620             18.9%               0.0%               0.0%
# 1  37203     10,201             11.9%               4.5%               7.8%
# 2  37204      6,080              4.1%               1.6%               4.3%
# 3  37205     10,999              4.6%               1.4%               4.0%
# 4  37206     11,584              8.4%               4.4%               8.5%
#
#   $25,000 to $34,999 $35,000 to $49,999 $50,000 to $74,999 $75,000 to $99,999  \
# 0               2.6%               4.5%              13.1%              29.2%
# 1               4.2%              12.8%              25.3%              10.4%
# 2               6.0%              10.1%              14.0%              13.4%
# 3               4.2%               7.5%              10.9%              13.5%
# 4               6.9%               9.0%              18.1%              10.5%
#
# ...

# %%
income_by_zip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ZIP                      20 non-null     int64
#  1   population               20 non-null     object
#  2   Less than $10,000        20 non-null     object
#  3   $10,000 to $14,999       20 non-null     object
#  4   $15,000 to $24,999       20 non-null     object
#  5   $25,000 to $34,999       20 non-null     object
#  6   $35,000 to $49,999       20 non-null     object
#  7   $50,000 to $74,999       20 non-null     object
#  8   $75,000 to $99,999       20 non-null     object
#  9   $100,000 to $149,999     20 non-null     object
#  10  $150,000 to $199,999     20 non-null     object
#  11  $200,000 or more         20 non-null     object
#  12  Median income (dollars)  20 non-null     object
#  13  Mean income (dollars)    20 non-null     object
# ...

# %%
income_by_zip.Mean income (dollars)

# %%
population_by_zip[Median_income_(dollars)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-e14aa68e1720> in <module>
# ----> 1 population_by_zip[Median_income_(dollars)]
#
# NameError: name 'population_by_zip' is not defined

# %%
income_by_zip.plot.barh()

# %%
plt.figure(figsize = (12,10))
plt.bar('zip', 'income', data = )
plt.xticks(month_count['month'])
plt.xlabel('Month')
plt.ylabel('Count')
